# %% [markdown]
# # Data Visualization using Python

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.ticker as mtick

# %% [markdown]
# ## Bar Plot
#
# A bar plot is a type of chart that presents categorical data with rectangular bars, where the length of each bar corresponds to the value or frequency of a particular category.
# -   The x-axis of the bar plot represents the categories or groups being compared, while the y-axis represents the values or frequencies associated with each category.
# -   Each bar in the plot represents a specific category, allowing for a visual comparison of the values or frequencies between different categories.
#
# Bar plots can be used to:
# -   Compare the values or frequencies of different categories and identify any significant differences or patterns.
# -   Display and summarize categorical data in a clear and intuitive manner.
# -   Communicate distributions, proportions, or percentages within different categories.

# %% [markdown]
# #### Bar plot by Matplotlib

# %%
height = [10,15,5,20]

bars = ['Apple', 'Orange', 'Lemon', 'Lime']

plt.bar(bars, height)

plt.xlabel('Bars')
plt.ylabel('Height')
plt.show()

# %%
height = [10,15,5,20]

bars = ['Apple', 'Orange', 'Lemon', 'Lime']

x_pos = np.arange(len(bars))
print(x_pos)

plt.bar(x_pos, height)
plt.xticks(x_pos, bars)

plt.xlabel('Bars')
plt.ylabel('Height')
plt.show()
# Out:
# [0 1 2 3]

# %% [markdown]
# #### By Seaborn

# %%
height = [10,15,5,20]
bars = ['Apple', 'Orange', 'Lemon', 'Lime']

sns.set_theme(style="whitegrid")

sns.barplot(x=bars, y=height)

plt.xlabel('Bars')
plt.ylabel('Height')
plt.show()

# %%
height = [10,15,5,20]
bars = ['Apple', 'Orange', 'Lemon', 'Lime']

data = { 'Bars': bars, 'Height': height}
df = pd.DataFrame(data)
print(df.head())

sns.set_theme(style="whitegrid")

sns.barplot(x='Bars', y='Height', data=df)
# Out:
#      Bars  Height
# 0   Apple      10
# 1  Orange      15
# 2   Lemon       5
# 3    Lime      20
# <Axes: xlabel='Bars', ylabel='Height'>

# %% [markdown]
# #### Adjustment the plot

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 20}

plt.bar(data.keys(), data.values())

plt.xlabel('Fruits')
plt.ylabel('Counts')

plt.xticks(color='orange')
plt.yticks(color='Yellow')
plt.show()

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 20}
names = list(data.keys())
values = list(data.values())

sns.barplot(x=names, y=values)

plt.xlabel('Fruits')
plt.ylabel('Counts')

plt.xticks(color='orange')
plt.yticks(color='Yellow')
plt.show()

# %% [markdown]
# #### Rotate x-ticks

# %%
height = [3, 12, 5, 18, 45]
bars = ["very long group name 1","very long group name 2","very long group name 3","very long group name 4","very long group name 5"]

sns.barplot(x=bars, y = height)
plt.xticks(rotation=90)

plt.xlabel('Bars')
plt.ylabel('Height')
plt.show()

# %%
# By Seaborn

# Create data
height = [3, 12, 5, 18, 45]
bars = ["very long group name 1", "very long group name 2", "very long group name 3", "very long group name 4", "very long group name 5"]

# Create bar plot using Seaborn
sns.barplot(x=bars, y=height)
plt.xticks(rotation=90)

# Add labels to the x-axis and y-axis
plt.xlabel('Bars')
plt.ylabel('Height')
plt.show()

# %% [markdown]
# #### Set column width

# %%
data = { 'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 20}
names = list(data.keys())
values = list(data.values())

ax = plt.axes()
ax.bar(names, values, color='blue', width=0.5)
ax.set_xlabel('Fruit')
ax.set_ylabel('Quantity')
ax.set_title('Fruit Quantities')
plt.show()

# %% [markdown]
# #### Horizontal Bar Plot

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 20}
names = list(data.keys())
values = list(data.values())

ax = plt.axes()

ax.barh(names,values, color='blue')

ax.set_xlabel('Quantitiy')
ax.set_ylabel('Fruit')
ax.set_title('Fruit Quantities')
plt.show()

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 20}
names = list(data.keys())
values = list(data.values())

sns.barplot(x=values, y=names, color='blue')
plt.xlabel('Quantity')
plt.ylabel('Fruit')
plt.title('Fruit Quantities')
plt.show()

# %% [markdown]
#  #### Control order
# A bar chart is always more insightful when ordered. It allows to understand how items are ranked much quicker.

# %%
# By Matplotlib
df = pd.DataFrame ({
    'Group':  ['Apple', 'Orange', 'Lemon', 'Lime'],
    'Value': [10,15,5,20]
})

# Sort the table
df = df.sort_values(by=['Value'],ascending=False)

ax = plt.axes()

# Create horizontal bars
ax.barh(y=df.Group, width=df.Value, color="blue")

# Add title
ax.set_xlabel('Quantity')
ax.set_ylabel('Fruit')
ax.set_title('Fruit Quantities')
plt.show()

# %%
df = pd.DataFrame({
    'Group':  ['Apple', 'Orange', 'Lemon', 'Lime'],
    'Value': [10,15,5,20]
})

df = df.sort_values(by=['Value'], ascending=True)

sns.set(style="whitegrid")

ax = sns.barplot(x= 'Value', y='Group', data=df, color='blue' )

ax.set(xlabel='Quantity', ylabel='Fruit', title='Fruit Quantities')
plt.show()

# %% [markdown]
# ## Grouped Bar Plot

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.25

print('x: ',x)
print('Men: ',x-width/2)
print('Women: ',x+width/2)

fig, ax = plt.subplots()
ax.bar(x - width/2, men_means, width=width, label='Men', edgecolor='k')
ax.bar(x + width/2, women_means, width=width, label='Women', edgecolor='k')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.legend()
plt.show()
# Out:
# x:  [0 1 2 3 4]
# Men:  [-0.125  0.875  1.875  2.875  3.875]
# Women:  [0.125 1.125 2.125 3.125 4.125]

# %% [markdown]
# #### Improvement

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.25

fig,ax = plt.subplots()
ax.grid(linestyle='--', color='0.75', axis = 'y')

p1 = ax.bar(x- width/2, men_means, width, label='Men')
p2 = ax.bar(x + width/2, women_means, width, label= 'Women')

ax.setylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)

# %% [markdown]
# ## Stacked bar plot

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

width = 0.25

fig,ax = plt.subplots()
ax.grid(linestyle='--', color='0.75', axis = 'y')

p1 = ax.bar(labels, men_means, width, label='Men')
p2 = ax.bar(labels, women_means, width ,label='Women', bottom=men_means)

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

ax.bar_label(p1, label_type='center')
ax.bar_label(p2, label_type='center')
ax.bar_label(p2)
ax.set_ylim(0,70)
# Out:
# (0.0, 70.0)

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

width = 0.25  # the width of the bars

fig, ax = plt.subplots()
ax.grid(linestyle='--', color='0.75', axis='y')

p1 = ax.bar(labels, men_means, width, label='Men')
p2 = ax.bar(labels, women_means, width, bottom=men_means, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

# Calculate totals for each group
totals = [men_means[i] + women_means[i] for i in range(len(labels))]

# Label only the totals
ax.bar_label(p2, labels=totals)

ax.set_ylim(0, 70)

plt.show()

# %% [markdown]
# ## Grouped Stacked Bar Plot

# %%
def subplot_sentiment(df1, df2, ax):
    colors1 = {'POS': '#4caf50', 'NEU': '#ff9800', 'NEG': '#e51c23'}
    colors2 = {'POS': '#8cbf5b', 'NEU': '#ffd966', 'NEG': '#ff7f7f'}
    barWidth = 0.35
    print(df1.head())
    print(len(df1))
    
    r1 = np.arange(len(df1))
    r2 = [x+ barWidth for x in r1]
    
    ax.set_xlim(r1.min() - barWidth, r1.max() + barWidth*2)
    
    ax.bar(r1, df1['POS'], color=colors1)

# %% [markdown]
# ## Lollipop chart
